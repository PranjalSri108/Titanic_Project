# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
from preprocess import load_data, clean_data, engineer_features, encode_and_scale, save_outputs

# %%
# Load data
df = load_data("~/heethrark_internship/ml_projects/titanic_project/data/train.csv")
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    object
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    object
#  6   SibSp        891 non-null    object
#  7   Parch        891 non-null    object
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    object
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: object(12)
# memory usage: 83.7+ KB
#   PassengerId Survived Pclass  \
# 0           1        0      3
# 1           2        1      1
# 2           3        1      3
# 3           4        1      1
# 4           5        0      3
#
# ...

# %%
# Clean data
df_cleaned = clean_data(df)
df_cleaned.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
# Feature engineering
df_features = engineer_features(df_cleaned)
df_features[['Title', 'FamilySize', 'IsAlone', 'AgeBin', 'FareBin']].head()
# Out:
#   Title  FamilySize  IsAlone   AgeBin   FareBin
# 0    Mr           2        0  AgeBin2  FareBin1
# 1   Mrs           2        0  AgeBin4  FareBin5
# 2  Miss           1        1  AgeBin3  FareBin2
# 3   Mrs           2        0  AgeBin4  FareBin5
# 4    Mr           1        1  AgeBin4  FareBin2

# %%
# Encoding and scaling
df_final = encode_and_scale(df_features)
df_final.info()
df_final.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 30 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Survived          891 non-null    object
#  1   Age               891 non-null    float64
#  2   SibSp             891 non-null    object
#  3   Parch             891 non-null    object
#  4   Fare              891 non-null    float64
#  5   FamilySize        891 non-null    int64
#  6   IsAlone           891 non-null    int64
#  7   Sex_female        891 non-null    bool
#  8   Sex_male          891 non-null    bool
#  9   Embarked_C        891 non-null    bool
#  10  Embarked_Q        891 non-null    bool
#  11  Embarked_S        891 non-null    bool
#  12  Pclass_1          891 non-null    bool
#  13  Pclass_2          891 non-null    bool
#  14  Pclass_3          891 non-null    bool
#  15  Title_Master      891 non-null    bool
# ...

# %%
# Save outputs
save_outputs(df_final, output_dir='~/heethrark_internship/ml_projects/titanic_project/output')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 2
#       1 # Save outputs
# ----> 2 save_outputs(df_final, output_dir='~/heethrark_internship/ml_projects/titanic_project/output')
#
# File ~/heethrark_internship/ml_projects/titanic_project/preprocess.py:67, in save_outputs(df, output_dir)
#      65 df.to_csv(f'{output_dir}/cleaned.csv', index=False)
#      66 X = df.drop(columns=['Survived'], errors='ignore').values
# ---> 67 np.save(f'{output_dir}/final_features.npy', X)
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/npyio.py:542, in save(file, arr, allow_pickle, fix_imports)
#     540     if not file.endswith('.npy'):
#     541         file = file + '.npy'
# --> 542     file_ctx = open(file, "wb")
#     544 with file_ctx as fid:
#     545     arr = np.asanyarray(arr)
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 2
#       1 X = df.drop(columns=['Survived'], errors='ignore').values
# ----> 2 X.describe()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'describe'
